# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('subconjunto.csv')
data
# Out:
#        cole_depto_ubicacion  cole_mcpio_ubicacion estu_depto_presentacion  \
# 0                 SANTANDER  EL CARMEN DE CHUCURÍ               SANTANDER
# 1                 SANTANDER           BUCARAMANGA               SANTANDER
# 2                 SANTANDER       BARRANCABERMEJA               SANTANDER
# 3                 SANTANDER            CAPITANEJO               SANTANDER
# 4                 SANTANDER      SABANA DE TORRES               SANTANDER
# ...                     ...                   ...                     ...
# 339768            SANTANDER         FLORIDABLANCA               SANTANDER
# 339769            SANTANDER               SAN GIL               SANTANDER
# 339770            SANTANDER           PIEDECUESTA               SANTANDER
# 339771            SANTANDER      SABANA DE TORRES               SANTANDER
# 339772            SANTANDER              COROMORO               SANTANDER
#
#        estu_depto_reside fami_estratovivienda fami_tienecomputador  \
# ...

# %%
(data.isna().sum())/len(data) *100
# Out:
# cole_depto_ubicacion        0.000000
# cole_mcpio_ubicacion        0.000000
# estu_depto_presentacion     0.000000
# estu_depto_reside           0.000000
# fami_estratovivienda        2.054901
# fami_tienecomputador        2.129657
# fami_tieneinternet          1.890968
# punt_global                39.174684
# dtype: float64

# %%
data_limpia =pd.read_csv('saber11_santander_limpio.csv')
data_limpia
# Out:
#        cole_depto_ubicacion cole_mcpio_ubicacion estu_depto_presentacion  \
# 0                 SANTANDER      BARRANCABERMEJA               SANTANDER
# 1                 SANTANDER           CAPITANEJO               SANTANDER
# 2                 SANTANDER     SABANA DE TORRES               SANTANDER
# 3                 SANTANDER     SABANA DE TORRES               SANTANDER
# 4                 SANTANDER                 OIBA               SANTANDER
# ...                     ...                  ...                     ...
# 206663            SANTANDER        FLORIDABLANCA               SANTANDER
# 206664            SANTANDER              SAN GIL               SANTANDER
# 206665            SANTANDER          PIEDECUESTA               SANTANDER
# 206666            SANTANDER     SABANA DE TORRES               SANTANDER
# 206667            SANTANDER             COROMORO               SANTANDER
#
#        estu_depto_reside fami_estratovivienda fami_tienecomputador  \
# ...

# %%
((data_limpia =='NO REPORTA').sum())/len(data_limpia) *100
# Out:
# cole_depto_ubicacion       0.000000
# cole_mcpio_ubicacion       0.000000
# estu_depto_presentacion    0.000000
# estu_depto_reside          0.000000
# fami_estratovivienda       3.217237
# fami_tienecomputador       1.825150
# fami_tieneinternet         2.858691
# punt_global                0.000000
# dtype: float64
